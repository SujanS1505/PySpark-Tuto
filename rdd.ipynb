# %%
import os
import sys


os.environ['PYSPARK_PYTHON'] = sys.executable
os.environ['PYSPARK_DRIVER_PYTHON'] = sys.executable

from pyspark.sql import SparkSession
spark=SparkSession.builder.appName("CountExample").getOrCreate()

numbers=[1,2,3,4,5]
rdd=spark.sparkContext.parallelize(numbers)

print(rdd.collect())
# Out:
# [1, 2, 3, 4, 5]

# %%
data=[("Ram",34),("Sam",36),("Arun",30),("vikram",29)]
rdd=spark.sparkContext.parallelize(data)

print(rdd.collect())

print(rdd.count())

print(rdd.first())
# Out:
# [('Ram', 34), ('Sam', 36), ('Arun', 30), ('vikram', 29)]
# 4
# ('Ram', 34)

# %%
taken=rdd.take(2)
print(taken)
# Out:
# [('Ram', 34), ('Sam', 36)]

# %% [markdown]
# RDD Transformations

# %%
mapped_rdd=rdd.map(lambda x: (x[0].upper(), x[1]))
print(mapped_rdd.collect())
# Out:
# [('RAM', 34), ('SAM', 36), ('ARUN', 30), ('VIKRAM', 29)]

# %%
filtered_rdd=rdd.filter(lambda x: x[1]>35)
print(filtered_rdd.collect())
# Out:
# [('Sam', 36)]

# %%
sorted_rdd=rdd.sortBy(lambda x: x[1])
print(sorted_rdd.collect())
# Out:
# [('vikram', 29), ('Arun', 30), ('Ram', 34), ('Sam', 36)]
